# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data_set_1= sns.load_dataset("anscombe")
data_set_2= sns.load_dataset("car_crashes")
data_set_3= sns.load_dataset("tips")
data_set_4= sns.load_dataset("brain_networks")

# %%
data_set_2
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sns.scatterplot(x="total",y="speeding" ,data=data_set_2,hue="abbrev")
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %%
sns.barplot(x="speeding",y="alcohol",data=data_set_2)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
sns.boxplot(x="speeding",y="alcohol",data=data_set_2)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
data_set_3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x="day",y="tip",data=data_set_3,hue="day",dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="tip", y="total_bill", data=data_set_3,dropna=True,kind="reg" )

# %%
sns.pairplot(data_set_4.select_dtypes("1"),hue="2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 sns.pairplot(data_set_4.select_dtypes("1"),hue="2")
#
# File /workspace/test/lib/python3.12/site-packages/pandas/core/frame.py:5073, in DataFrame.select_dtypes(self, include, exclude)
#    5070             converted_dtypes.append(infer_dtype_from_object(dtype))
#    5071     return frozenset(converted_dtypes)
# -> 5073 include = check_int_infer_dtype(include)
#    5074 exclude = check_int_infer_dtype(exclude)
#    5076 for dtypes in (include, exclude):
#
# File /workspace/test/lib/python3.12/site-packages/pandas/core/frame.py:5070, in DataFrame.select_dtypes.<locals>.check_int_infer_dtype(dtypes)
#    5068         converted_dtypes.extend([np.float64, np.float32])
#    5069     else:
# -> 5070         converted_dtypes.append(infer_dtype_from_object(dtype))
#    5071 return frozenset(converted_dtypes)
# ...

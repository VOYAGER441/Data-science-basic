# %%
import pandas as pd

# %%
 s= pd.Series([10,20,30,40],index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
df=pd.DataFrame([
    {
        "name":"Mainak",
        "age":21
    },
    {
        "name":"Anyriya",
        "age":22
    }
])

# %%
df
# Out:
#       name  age
# 0   Mainak   21
# 1  Anyriya   22

# %%
df=pd.DataFrame({
    "name":["Mainak","Anuriya"],
    "age":[21,22]    
})

# %%
df
# Out:
#       name  age
# 0   Mainak   21
# 1  Anuriya   22

# %%
df=pd.read_csv("./agreement.csv")

# %%
df
# Out:
#            Agreement
# 0     Strongly Agree
# 1              Agree
# 2            Neutral
# 3           Disagree
# 4  Strongly Disagree

# %%
df=pd.read_excel("file_example_XLS_10.xlsx",index_col=0)

# %%
df
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0
# 1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3     Philip       Gent    Male         France   36  21/05/2015  2587
# 4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
df=pd.read_json("mtcars.json",lines=True)

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0
# 1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3     Philip       Gent    Male         France   36  21/05/2015  2587
# 4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
df.tail()
# Out:
#   First Name Last Name  Gender        Country  Age        Date    Id
# 0
# 5    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 6     Gaston     Brumm    Male  United States   24  21/05/2015  2554
# 7       Etta      Hurn  Female  Great Britain   56  15/10/2017  3598
# 8    Earlean    Melgar  Female  United States   27  16/08/2016  2456
# 9   Vincenza   Weiland  Female  United States   40  21/05/2015  6548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 1 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  9 non-null      object
#  1   Last Name   9 non-null      object
#  2   Gender      9 non-null      object
#  3   Country     9 non-null      object
#  4   Age         9 non-null      int64
#  5   Date        9 non-null      object
#  6   Id          9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 576.0+ bytes

# %%
df.describe()
# Out:
#              Age           Id
# count   9.000000     9.000000
# mean   35.888889  2989.333333
# std    13.147666  1511.344517
# min    24.000000  1562.000000
# 25%    25.000000  2456.000000
# 50%    32.000000  2554.000000
# 75%    40.000000  3549.000000
# max    58.000000  6548.000000

# %%
df.shape
# Out:
# (9, 7)

# %%
df.columns
# Out:
# Index(['First Name', 'Last Name', 'Gender', 'Country', 'Age', 'Date', 'Id'], dtype='object')

# %%
df.index
# Out:
# Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name=0)

# %%
df.Age
# Out:
# 0
# 1    32
# 2    25
# 3    36
# 4    25
# 5    58
# 6    24
# 7    56
# 8    27
# 9    40
# Name: Age, dtype: int64

# %%
df.loc[5]
# Out:
# First Name          Nereida
# Last Name           Magwood
# Gender               Female
# Country       United States
# Age                      58
# Date             16/08/2016
# Id                     2468
# Name: 5, dtype: object

# %%
df.loc[0:5,["First Name","Age"]]
# Out:
#   First Name  Age
# 0
# 1      Dulce   32
# 2       Mara   25
# 3     Philip   36
# 4   Kathleen   25
# 5    Nereida   58

# %%
df.sort_values("Age")
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0
# 6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 3     Philip       Gent    Male         France   36  21/05/2015  2587
# 9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548
# 7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
df["Age"]=df["Age"]-10

# %%
df=df.drop(columns=["Date"])

# %%
df
# Out:
#   First Name  Last Name  Gender        Country  Age    Id
# 0
# 1      Dulce      Abril  Female  United States   32  1562
# 2       Mara  Hashimoto  Female  Great Britain   25  1582
# 3     Philip       Gent    Male         France   36  2587
# 4   Kathleen     Hanner  Female  United States   25  3549
# 5    Nereida    Magwood  Female  United States   58  2468
# 6     Gaston      Brumm    Male  United States   24  2554
# 7       Etta       Hurn  Female  Great Britain   56  3598
# 8    Earlean     Melgar  Female  United States   27  2456
# 9   Vincenza    Weiland  Female  United States   40  6548

# %%
df.isna()
# Out:
#    First Name  Last Name  Gender  Country    Age     Id
# 0
# 1       False      False   False    False  False  False
# 2       False      False   False    False  False  False
# 3       False      False   False    False  False  False
# 4       False      False   False    False  False  False
# 5       False      False   False    False  False  False
# 6       False      False   False    False  False  False
# 7       False      False   False    False  False  False
# 8       False      False   False    False  False  False
# 9       False      False   False    False  False  False

# %%
df.isna().sum()
# Out:
# First Name    0
# Last Name     0
# Gender        0
# Country       0
# Age           0
# Id            0
# dtype: int64

# %%
df=pd.read_csv("synthetic_dataset.csv")

# %%
df
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0       NaN      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
df.shape
# Out:
# (4362, 5)

# %%
df.isna().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %%
df1=df

# %%
df1=df1.dropna()

# %%
df1.isna().sum()
# Out:
# Category    0
# Price       0
# Rating      0
# Stock       0
# Discount    0
# dtype: int64

# %%
df1.describe()
# Out:
#              Price       Rating     Discount
# count  4188.000000  2312.000000  3970.000000
# mean   5016.970630     3.038293    24.516625
# std    2839.984813     1.143074    14.347164
# min     102.000000     1.000366     0.000000
# 25%    2628.250000     2.069490    12.000000
# 50%    4996.500000     3.082060    25.000000
# 75%    7418.000000     4.008620    37.000000
# max    9999.000000     4.997818    49.000000

# %%
df1=df1.fillna(value=1)

# %%
df1
# Out:
#      Category   Price    Rating         Stock  Discount
# 6           C   667.0  3.668341      In Stock      41.0
# 7           A  7125.0  4.983998  Out of Stock       7.0
# 8           A  2777.0  2.678384      In Stock       6.0
# 11          A  3772.0  4.890750      In Stock      45.0
# 15          A  7936.0  3.032832      In Stock      44.0
# ...       ...     ...       ...           ...       ...
# 4313        A  4167.0  2.432036  Out of Stock      22.0
# 4320        C  7630.0  3.475273      In Stock       0.0
# 4333        D  2424.0  4.716295      In Stock      49.0
# 4342        D  9847.0  3.667649  Out of Stock      49.0
# 4343        B   843.0  2.752754  Out of Stock      48.0
#
# [540 rows x 5 columns]

# %%
df1.duplicated()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
df1["Rating"].plot(kind="hist")
# df1.plot(x="year",y="Rating")
# Out:
# <Axes: ylabel='Frequency'>
